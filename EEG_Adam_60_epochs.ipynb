# %% [markdown]
# <a href="https://colab.research.google.com/github/frh02/ProjectEEG/blob/master/EEG_Adam_60_epochs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os
import numpy as np
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, Activation
from keras.layers import Flatten, Dense, Dropout
from matplotlib import pyplot as plt
# %matplotlib inline

print('TensorFlow version:', tf.__version__)
print('Is using GPU?', tf.test.is_gpu_available())
# Out:
# TensorFlow version: 2.2.0
# WARNING:tensorflow:From <ipython-input-2-ad5134fc0fa9>:11: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# Using TensorFlow backend.
# Is using GPU? True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
img_rows=51
img_cols=51
num_channel=3
num_epoch=50

batch_size=128

# %%
import os

import cv2

# %%
PATH = os.getcwd()
# Define data path
data_path =  '/content/drive/My Drive/Data_all_compress' #'Train'
data_dir_list = os.listdir(data_path)
data_dir_list
# Out:
# ['Anesthesia_Low', 'Anesthesia_Deep', 'Anesthesia_Okay']

# %%
num_classes = 3

#labels_name={'Ok':0,'Deep':1,'Light':2}
#class_names=['Ok', 'Light', 'Deep']
class_names=['Anesthesia_Low', 'Anesthesia_Deep','Anesthesia_Okay']
labels_name={'Anesthesia_Low':0,'Anesthesia_Deep':1, 'Anesthesia_Okay':0}
img_data_list=[]
labels_list = []

# %%
for d in data_dir_list:
  print(d)
  print(os.listdir(data_path+'/' +d))
# Out:
# Anesthesia_Low
# ['Pat11LOW_1534.png', 'Pat11LOW_1535.png', 'Pat11LOW_1536.png', 'Pat11LOW_1537.png', 'Pat11LOW_1538.png', 'Pat11LOW_1539.png', 'Pat11LOW_1541.png', 'Pat11LOW_1540.png', 'Pat11LOW_1543.png', 'Pat11LOW_1542.png', 'Pat11LOW_1544.png', 'Pat11LOW_1545.png', 'Pat11LOW_1546.png', 'Pat11LOW_1548.png', 'Pat11LOW_1547.png', 'Pat11LOW_1549.png', 'Pat11LOW_1551.png', 'Pat11LOW_1550.png', 'Pat11LOW_1552.png', 'Pat11LOW_1553.png', 'Pat11LOW_1554.png', 'Pat11LOW_1555.png', 'Pat11LOW_1556.png', 'Pat11LOW_1557.png', 'Pat11LOW_1558.png', 'Pat11LOW_1559.png', 'Pat11LOW_1561.png', 'Pat11LOW_1560.png', 'Pat11LOW_1563.png', 'Pat11LOW_1562.png', 'Pat11LOW_1564.png', 'Pat11LOW_1565.png', 'Pat11LOW_1566.png', 'Pat11LOW_1567.png', 'Pat11LOW_1568.png', 'Pat11LOW_1569.png', 'Pat11LOW_1570.png', 'Pat11LOW_1571.png', 'Pat11LOW_1573.png', 'Pat11LOW_1572.png', 'Pat11LOW_1574.png', 'Pat11LOW_1575.png', 'Pat11LOW_1576.png', 'Pat11LOW_1578.png', 'Pat11LOW_1577.png', 'Pat11LOW_1579.png', 'Pat11LOW_1581.png', 'Pat11LOW_1580.png', 'Pat11LOW_1583.png', 'Pat11LOW_1582.png', 'Pat11LOW_1584.png', 'Pat11LOW_1586.png', 'Pat11LOW_1585.png', 'Pat11LOW_1588.png', 'Pat11LOW_1587.png', 'Pat11LOW_1589.png', 'Pat11LOW_1590.png', 'Pat11LOW_1591.png', 'Pat11LOW_1592.png', 'Pat11LOW_1593.png', 'Pat11LOW_1594.png', 'Pat11LOW_1595.png', 'Pat11LOW_1596.png', 'Pat11LOW_1597.png', '
# %%
for dataset in data_dir_list:
  img_list=os.listdir(data_path+'/' +dataset)
  print ('Loading the images of dataset-'+'{}\n'.format(dataset))
  label = labels_name[dataset]
  for img in img_list:
    input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
    input_img_resize=cv2.resize(input_img,(128,128))
    img_data_list.append(input_img_resize)
    labels_list.append(label)
# Out:
# Loading the images of dataset-Anesthesia_Low
#
# Loading the images of dataset-Anesthesia_Deep
#
# Loading the images of dataset-Anesthesia_Okay

# %%
img_data = np.array(img_data_list)
img_data = img_data.astype('float32')
img_data /= 255.
print (img_data.shape)
# Out:
# (7996, 128, 128, 3)

# %%
import keras
import keras.utils
from keras import utils as np_utils

labels = np.array(labels_list)
# print the count of number of samples for different classes
print(np.unique(labels,return_counts=True))
# convert class labels to on-hot encoding
Y = keras.utils.to_categorical(labels, num_classes)
# Out:
# (array([0, 1]), array([5324, 2672]))

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

#Shuffle the dataset
x,y = shuffle(img_data,Y, random_state=2)

# %%
# Split the dataset
x_train, x_test, y_train, y_test = train_test_split(img_data, Y, test_size=0.3)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (5597, 128, 128, 3)
# (2399, 128, 128, 3)
# (5597, 3)
# (2399, 3)

# %%
def show_random_eg(x,y,p):
    indices=np.random.choice(range(x.shape[0]),10,replace=False)
    x=x[indices]
    y=y[indices]
    p=p[indices]
    
    plt.figure(figsize=(20,10))
    
    for i in range(10):
        plt.subplot(2,5,i+1)
        plt.imshow(x[i])
        plt.xticks([])
        plt.yticks([])
        csfont = {'fontname':'Comic Sans MS'}
        hfont = {'fontname':'Helvetica'}
        col='purple' if np.argmax(y[i])==np.argmax(p[i]) else 'red'
        #print(class_names[np.argmax(p[i])])
        
        plt.xlabel(class_names[np.argmax(p[i])],color=col, fontsize=20,**hfont)
    plt.show()

# %%
show_random_eg(x_train, y_train, y_train)
# Out:
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.

# %%
show_random_eg(x_test, y_test, y_test)

# %%
input_shape=img_data[0].shape
input_shape
# Out:
# (128, 128, 3)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (5597, 128, 128, 3) (5597, 3)
# (2399, 128, 128, 3) (2399, 3)

# %% [markdown]
# # CHECKPOINT

# %%
from keras.callbacks import ModelCheckpoint
from keras.callbacks import LearningRateScheduler

# %%
class LearningRateSchedulerPerBatch(LearningRateScheduler):
    """ Callback class to modify the default learning rate scheduler to operate each batch"""
    def __init__(self, schedule, verbose=0):
        super(LearningRateSchedulerPerBatch, self).__init__(schedule, verbose)
        self.count = 0  # Global batch index (the regular batch argument refers to the batch index within the epoch)

    def on_epoch_begin(self, epoch, logs=None):
        pass

    def on_epoch_end(self, epoch, logs=None):
        pass

    def on_batch_begin(self, batch, logs=None):
        super(LearningRateSchedulerPerBatch, self).on_epoch_begin(self.count, logs)

    def on_batch_end(self, batch, logs=None):
        super(LearningRateSchedulerPerBatch, self).on_epoch_end(self.count, logs)
        self.count += 1

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.layers import Dropout, Flatten, Input, Dense ,Activation
from tensorflow.keras.optimizers import Adam

def create_model():
    
    def add_conv_block(model, num_filters):
        
        model.add(Conv2D(num_filters, 3, activation='relu', padding='same'))
        model.add(BatchNormalization())
        model.add(Conv2D(num_filters, 3, activation='relu', padding='valid'))
        model.add(MaxPooling2D(pool_size=2))
        model.add(Dropout(0.2))

        return model
    
    model = tf.keras.models.Sequential()
    model.add(Input(shape=(128, 128, 3)))
    model = add_conv_block(model,96)
    model = add_conv_block(model, 32)
    model = add_conv_block(model, 64)
    model = add_conv_block(model, 128)
    model = add_conv_block(model,256)
    
  

    
    model.add(Flatten())
    #model.add(Dense(4096))
   #model.add(Activation('tanh'))
   #model.add(Dropout(0.5))
   # model.add(Dense(4096))
   # model.add(Activation('relu'))
   # model.add(Dropout(0.5))
    model.add(Dense(3, activation='softmax'))
    opt =Adam(
    lr=0.001,beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0
    )
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    return model

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='cnn_eeg.png',show_shapes=True, show_layer_names=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-e3043b09af03> in <module>()
#       1 from keras.utils.vis_utils import plot_model
# ----> 2 plot_model(model, to_file='cnn_eeg.png',show_shapes=True, show_layer_names=True)
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/vis_utils.py in plot_model(model, to_file, show_shapes, show_layer_names, rankdir, expand_nested, dpi)
#     238     """
#     239     dot = model_to_dot(model, show_shapes, show_layer_names, rankdir,
# --> 240                        expand_nested, dpi)
#     241     _, extension = os.path.splitext(to_file)
#     242     if not extension:
#
# /usr/local/lib/python3.6/dist-packages/keras/utils/vis_utils.py in model_to_dot(model, show_shapes, show_layer_names, rankdir, expand_nested, dpi, subgraph)
#     167             node_key = layer.name + '_ib-' + str(i)
#     168             if node_key in model._network_nodes:
# --> 169                 for inbound_layer in node.inbound_layers:
#     170                     inbound_layer_id = str(id(inbound_layer))
#     171                     if not expand_nested:
#
# TypeError: 'InputLayer' object is not iterable

# %%
if not os.path.isdir('/content/drive/My Drive/Colab Notebooks/modelsEEG'):
    os.mkdir('/content/drive/My Drive/Colab Notebooks/modelsEEG')

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 96)      2688
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 96)      384
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 126, 126, 96)      83040
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 63, 63, 96)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 63, 63, 96)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 63, 63, 32)        27680
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 63, 63, 32)        128
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 61, 61, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 30, 30, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 30, 30, 64)        256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 12, 12, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 6, 6, 256)         295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 3)                 3075
# =================================================================
# Total params: 1,290,147
# Trainable params: 1,288,995
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
# Start/resume training
#model.fit(x, y, callbacks=callbacks, initial_epoch=initial_epoch)

#Training
h=model.fit(
x_train,y_train,
validation_data=(x_test,y_test),
epochs=60,batch_size=64,
callbacks=[ tf.keras.callbacks.ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/modelsEEG/new_model_{epoch:03d}_{val_accuracy:.3f}.h5', 
                                            save_best_only=True,
                                            save_weights_only=False,
                                            monitor='val_accuracy')
          ],
initial_epoch=0

)
# Out:
# Epoch 1/60
# 88/88 [==============================] - 43s 489ms/step - loss: 0.5793 - accuracy: 0.6305 - val_loss: 0.4545 - val_accuracy: 0.6669
# Epoch 2/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.3342 - accuracy: 0.7547 - val_loss: 0.6867 - val_accuracy: 0.3331
# Epoch 3/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.2771 - accuracy: 0.7945 - val_loss: 0.5064 - val_accuracy: 0.3597
# Epoch 4/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.2555 - accuracy: 0.8204 - val_loss: 0.3728 - val_accuracy: 0.6665
# Epoch 5/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.2368 - accuracy: 0.8281 - val_loss: 0.6583 - val_accuracy: 0.6669
# Epoch 6/60
# 88/88 [==============================] - 39s 438ms/step - loss: 0.2283 - accuracy: 0.8369 - val_loss: 0.2792 - val_accuracy: 0.7757
# Epoch 7/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.2161 - accuracy: 0.8494 - val_loss: 0.2826 - val_accuracy: 0.7745
# Epoch 8/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.2209 - accuracy: 0.8478 - val_loss: 0.5885 - val_accuracy: 0.6724
# Epoch 9/60
# 88/88 [==============================] - 39s 438ms/step - loss: 0.2164 - accuracy: 0.8496 - val_loss: 0.1961 - val_accuracy: 0.8599
# Epoch 10/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.2068 - accuracy: 0.8592 - val_loss: 0.7226 - val_accuracy: 0.6669
# Epoch 11/60
# 88/88 [==============================] - 38s 435ms/step - loss: 0.1946 - accuracy: 0.8671 - val_loss: 0.2036 - val_accuracy: 0.8599
# Epoch 12/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.1928 - accuracy: 0.8658 - val_loss: 0.4818 - val_accuracy: 0.7241
# Epoch 13/60
# 88/88 [==============================] - 38s 435ms/step - loss: 0.1930 - accuracy: 0.8662 - val_loss: 0.2283 - val_accuracy: 0.8441
# Epoch 14/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.1983 - accuracy: 0.8635 - val_loss: 0.4533 - val_accuracy: 0.6865
# Epoch 15/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.1950 - accuracy: 0.8603 - val_loss: 0.3778 - val_accuracy: 0.7486
# Epoch 16/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.1773 - accuracy: 0.8787 - val_loss: 0.2089 - val_accuracy: 0.8629
# Epoch 17/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.1781 - accuracy: 0.8781 - val_loss: 0.8153 - val_accuracy: 0.6703
# Epoch 18/60
# 88/88 [==============================] - 38s 435ms/step - loss: 0.1876 - accuracy: 0.8717 - val_loss: 0.2108 - val_accuracy: 0.8604
# Epoch 19/60
# 88/88 [==============================] - 38s 435ms/step - loss: 0.1841 - accuracy: 0.8778 - val_loss: 0.3245 - val_accuracy: 0.7620
# Epoch 20/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.1700 - accuracy: 0.8807 - val_loss: 0.2296 - val_accuracy: 0.8416
# Epoch 21/60
# 88/88 [==============================] - 38s 435ms/step - loss: 0.1716 - accuracy: 0.8848 - val_loss: 0.3556 - val_accuracy: 0.7687
# Epoch 22/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.1727 - accuracy: 0.8858 - val_loss: 0.1936 - val_accuracy: 0.8745
# Epoch 23/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.1634 - accuracy: 0.8864 - val_loss: 0.2163 - val_accuracy: 0.8541
# Epoch 24/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.1600 - accuracy: 0.8941 - val_loss: 0.1915 - val_accuracy: 0.8716
# Epoch 25/60
# 88/88 [==============================] - 38s 435ms/step - loss: 0.1553 - accuracy: 0.8910 - val_loss: 0.2379 - val_accuracy: 0.8604
# Epoch 26/60
# 88/88 [==============================] - 38s 435ms/step - loss: 0.1552 - accuracy: 0.8994 - val_loss: 0.1950 - val_accuracy: 0.8724
# Epoch 27/60
# 88/88 [==============================] - 38s 435ms/step - loss: 0.1570 - accuracy: 0.8951 - val_loss: 0.2592 - val_accuracy: 0.8483
# Epoch 28/60
# 88/88 [==============================] - 38s 434ms/step - loss: 0.1395 - accuracy: 0.9064 - val_loss: 0.2344 - val_accuracy: 0.8583
# Epoch 29/60
# 88/88 [==============================] - 38s 434ms/step - loss: 0.1486 - accuracy: 0.8996 - val_loss: 0.2147 - val_accuracy: 0.8479
# Epoch 30/60
# 88/88 [==============================] - 38s 434ms/step - loss: 0.1484 - accuracy: 0.9033 - val_loss: 0.2187 - val_accuracy: 0.8666
# Epoch 31/60
# 88/88 [==============================] - 38s 435ms/step - loss: 0.1463 - accuracy: 0.9007 - val_loss: 0.4142 - val_accuracy: 0.8078
# Epoch 32/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.1344 - accuracy: 0.9116 - val_loss: 0.1882 - val_accuracy: 0.8766
# Epoch 33/60
# 88/88 [==============================] - 38s 435ms/step - loss: 0.1343 - accuracy: 0.9082 - val_loss: 0.3659 - val_accuracy: 0.7962
# Epoch 34/60
# 88/88 [==============================] - 38s 435ms/step - loss: 0.1301 - accuracy: 0.9164 - val_loss: 0.2966 - val_accuracy: 0.8370
# Epoch 35/60
# 88/88 [==============================] - 38s 434ms/step - loss: 0.1271 - accuracy: 0.9139 - val_loss: 0.3585 - val_accuracy: 0.7978
# Epoch 36/60
# 88/88 [==============================] - 38s 434ms/step - loss: 0.1189 - accuracy: 0.9226 - val_loss: 0.2321 - val_accuracy: 0.8562
# Epoch 37/60
# 88/88 [==============================] - 38s 434ms/step - loss: 0.1191 - accuracy: 0.9234 - val_loss: 0.2510 - val_accuracy: 0.8491
# Epoch 38/60
# 88/88 [==============================] - 38s 434ms/step - loss: 0.1237 - accuracy: 0.9194 - val_loss: 0.3996 - val_accuracy: 0.7612
# Epoch 39/60
# 88/88 [==============================] - 38s 434ms/step - loss: 0.1277 - accuracy: 0.9182 - val_loss: 0.2249 - val_accuracy: 0.8499
# Epoch 40/60
# 88/88 [==============================] - 38s 434ms/step - loss: 0.1110 - accuracy: 0.9334 - val_loss: 0.6609 - val_accuracy: 0.6719
# Epoch 41/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.1077 - accuracy: 0.9316 - val_loss: 0.2890 - val_accuracy: 0.8454
# Epoch 42/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.1053 - accuracy: 0.9325 - val_loss: 0.2617 - val_accuracy: 0.8595
# Epoch 43/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0952 - accuracy: 0.9425 - val_loss: 0.2475 - val_accuracy: 0.8466
# Epoch 44/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0794 - accuracy: 0.9503 - val_loss: 0.2609 - val_accuracy: 0.8687
# Epoch 45/60
# 88/88 [==============================] - 39s 438ms/step - loss: 0.0876 - accuracy: 0.9485 - val_loss: 0.2533 - val_accuracy: 0.8524
# Epoch 46/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0823 - accuracy: 0.9485 - val_loss: 0.2551 - val_accuracy: 0.8499
# Epoch 47/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0819 - accuracy: 0.9516 - val_loss: 0.2488 - val_accuracy: 0.8595
# Epoch 48/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0766 - accuracy: 0.9518 - val_loss: 0.3130 - val_accuracy: 0.8241
# Epoch 49/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0748 - accuracy: 0.9584 - val_loss: 0.2936 - val_accuracy: 0.8620
# Epoch 50/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.0758 - accuracy: 0.9564 - val_loss: 0.3761 - val_accuracy: 0.8499
# Epoch 51/60
# 88/88 [==============================] - 38s 436ms/step - loss: 0.0665 - accuracy: 0.9600 - val_loss: 0.2747 - val_accuracy: 0.8570
# Epoch 52/60
# 88/88 [==============================] - 39s 438ms/step - loss: 0.0618 - accuracy: 0.9611 - val_loss: 0.4307 - val_accuracy: 0.8566
# Epoch 53/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0654 - accuracy: 0.9594 - val_loss: 0.3790 - val_accuracy: 0.8454
# Epoch 54/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0601 - accuracy: 0.9655 - val_loss: 0.3471 - val_accuracy: 0.8649
# Epoch 55/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0593 - accuracy: 0.9655 - val_loss: 0.2765 - val_accuracy: 0.8208
# Epoch 56/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0462 - accuracy: 0.9737 - val_loss: 0.3813 - val_accuracy: 0.8545
# Epoch 57/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0414 - accuracy: 0.9773 - val_loss: 0.5205 - val_accuracy: 0.8533
# Epoch 58/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0501 - accuracy: 0.9703 - val_loss: 0.4433 - val_accuracy: 0.8595
# Epoch 59/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0518 - accuracy: 0.9700 - val_loss: 0.4156 - val_accuracy: 0.8416
# Epoch 60/60
# 88/88 [==============================] - 38s 437ms/step - loss: 0.0452 - accuracy: 0.9750 - val_loss: 0.3575 - val_accuracy: 0.8362

# %%
model = tf.keras.models.load_model('/content/drive/My Drive/Colab Notebooks/modelsEEG/new_model_032_0.877.h5')

# %%
results = model.evaluate(x_train, y_train, batch_size=64)
print('Train accuracy:', results[1]*100)
# Out:
# 88/88 [==============================] - 11s 120ms/step - loss: 0.1154 - accuracy: 0.9385
# Train accuracy: 93.85384917259216

# %%
results = model.evaluate(x_test, y_test, batch_size=64)
print('Test accuracy:', results[1]*100)
# Out:
# 38/38 [==============================] - 4s 108ms/step - loss: 0.1882 - accuracy: 0.8766
# Test accuracy: 87.66152858734131

# %%
#Final predictions

losses = h.history['loss']
accs = h.history['accuracy']
val_losses = h.history['val_loss']
val_accs = h.history['val_accuracy']
epochs = len(losses)

plt.figure(figsize=(12, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %%
model = tf.keras.models.load_model('/content/drive/My Drive/Colab Notebooks/modelsEEG/new_model_032_0.877.h5')
preds = model.predict(x_test)

# %%
show_random_eg(x_test, y_test, preds)

# %%
from sklearn.metrics import classification_report, confusion_matrix
  
# confusion matrix in sklearn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# confusion matrix
matrix = confusion_matrix(y_test,preds, labels=['Anestesia Low','Anesthesia Deep','Anesthesia Okay'])
print('Confusion matrix : \n',matrix)

# outcome values order in sklearn
tp, fn, fp, tn = confusion_matrix(y_test,preds,labels=['Anestesia Low','Anesthesia Deep','Anesthesia Okay']).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy
matrix = classification_report(y_test,preds,labels=['Anestesia Low','Anesthesia Deep','Anesthesia Okay'])
print('Classification report : \n',matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-a36434985e54> in <module>()
#       6
#       7 # confusion matrix
# ----> 8 matrix = confusion_matrix(y_test,preds, labels=['Anestesia Low','Anesthesia Deep','Anesthesia Okay'])
#       9 print('Confusion matrix : \n',matrix)
#      10
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     266
#     267     """
# --> 268     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     269     if y_type not in ("binary", "multiclass"):
#     270         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      88     if len(y_type) > 1:
#      89         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 90                          "and {1} targets".format(type_true, type_pred))
#      91
#      92     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and continuous-multioutput targets

# %% [markdown]
# # jhkhkjh

# %%
# Create model


model = Sequential()

model.add(Convolution2D(32, 3,3,border_mode='same',input_shape=input_shape))
model.add(Activation('relu'))
model.add(Convolution2D(32, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Convolution2D(64, 3, 3))
model.add(Activation('relu'))
#model.add(Convolution2D(64, 3, 3))
#model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=["accuracy"])
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(128, 128,..., padding="same")`
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3))`
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`
#   del sys.path[0]
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
# Viewing model_configuration

model.summary()
model.get_config()
model.layers[0].get_config()
model.layers[0].input_shape			
model.layers[0].output_shape			
model.layers[0].get_weights()
np.shape(model.layers[0].get_weights()[0])
model.layers[0].trainable
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      896
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 126, 126, 32)      9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 126, 126, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 61, 61, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 57600)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                3686464
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# _________________________________________________________________
# activation_5 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 3,715,299
# Trainable params: 3,715,299
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# True

# %%
# Training
#hist = model.fit(X_train, y_train, batch_size=16, nb_epoch=num_epoch, verbose=1, validation_data=(X_test, y_test))
hist = model.fit(X_train, y_train, batch_size=batch_size, nb_epoch=num_epoch,verbose=1, validation_split=0.2)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   This is separate from the ipykernel package so we can avoid doing imports until
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 3744 samples, validate on 936 samples
# Epoch 1/50
# 3744/3744 [==============================] - 241s 64ms/step - loss: 1.2156 - acc: 0.5182 - val_loss: 0.9303 - val_acc: 0.6303
# Epoch 2/50
# 3744/3744 [==============================] - 172s 46ms/step - loss: 0.9021 - acc: 0.6114 - val_loss: 0.8906 - val_acc: 0.6485
# Epoch 3/50
# 3744/3744 [==============================] - 168s 45ms/step - loss: 0.8382 - acc: 0.6370 - val_loss: 0.8273 - val_acc: 0.6795
# Epoch 4/50
# 3744/3744 [==============================] - 159s 42ms/step - loss: 0.7751 - acc: 0.6653 - val_loss: 0.7599 - val_acc: 0.6859
# Epoch 5/50
# 3744/3744 [==============================] - 258s 69ms/step - loss: 0.7271 - acc: 0.6763 - val_loss: 0.7813 - val_acc: 0.6848
# Epoch 6/50
# 3744/3744 [==============================] - 178s 47ms/step - loss: 0.7014 - acc: 0.6835 - val_loss: 0.7494 - val_acc: 0.6912
# Epoch 7/50
# 1160/3744 [========>.....................] - ETA: 1:45 - loss: 0.6721 - acc: 0.6819

# %%
# visualizing losses and accuracy
train_loss=hist.history['loss']
val_loss=hist.history['val_loss']
train_acc=hist.history['acc']
val_acc=hist.history['val_acc']
xc=range(num_epoch)

plt.figure(1,figsize=(7,5))
plt.plot(xc,train_loss)
plt.plot(xc,val_loss)
plt.xlabel('num of Epochs')
plt.ylabel('loss')
plt.title('train_loss vs val_loss')
plt.grid(True)
plt.legend(['train','val'])
#print plt.style.available # use bmh, classic,ggplot for big pictures
plt.style.use(['classic'])

plt.figure(2,figsize=(7,5))
plt.plot(xc,train_acc)
plt.plot(xc,val_acc)
plt.xlabel('num of Epochs')
plt.ylabel('accuracy')
plt.title('train_acc vs val_acc')
plt.grid(True)
plt.legend(['train','val'],loc=4)
#print plt.style.available # use bmh, classic,ggplot for big pictures
plt.style.use(['classic'])

# %%
# Evaluating the model

score = model.evaluate(X_test, y_test, show_accuracy=True, verbose=0)
print('Test Loss:', score[0])
print('Test accuracy:', score[1])

test_image = X_test[0:1]
print (test_image.shape)

print(model.predict(test_image))
print(model.predict_classes(test_image))
print(y_test[0:1])

# %%
model.evaluate(X_test, Y_test)[1]
