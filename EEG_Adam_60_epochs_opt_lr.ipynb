# %% [markdown]
# <a href="https://colab.research.google.com/github/frh02/ProjectEEG/blob/master/EEG_Adam_60_epochs_opt_lr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import os
import numpy as np
from keras.optimizers import Adam
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D, Activation
from keras.layers import Flatten, Dense, Dropout
from matplotlib import pyplot as plt
# %matplotlib inline

print('TensorFlow version:', tf.__version__)
print('Is using GPU?', tf.test.is_gpu_available())
# Out:
# TensorFlow version: 2.2.0
# WARNING:tensorflow:From <ipython-input-1-ad5134fc0fa9>:11: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# Using TensorFlow backend.
# Is using GPU? True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
img_rows=51
img_cols=51
num_channel=3
num_epoch=50

batch_size=128

# %%
import os

import cv2

# %%
PATH = os.getcwd()
# Define data path
data_path =  '/content/drive/My Drive/Data_all' #'Train'
data_dir_list = os.listdir(data_path)
data_dir_list
# Out:
# ['Anesthesia_Okay', 'Anesthesia_Low', 'Anesthesia_Deep']

# %%
num_classes = 3

#labels_name={'Ok':0,'Deep':1,'Light':2}
#class_names=['Ok', 'Light', 'Deep']
class_names=['Anesthesia_Okay', 'Anesthesia_Low','Anesthesia_Deep']
labels_name={'Anesthesia_Okay':0,'Anesthesia_Low':1, 'Anesthesia_Deep':0}
img_data_list=[]
labels_list = []

# %%
for d in data_dir_list:
  print(d)
  print(os.listdir(data_path+'/' +d))
# Out:
# Anesthesia_Okay
# ['Pat29OKAY_316.png', 'Pat29OKAY_317.png', 'Pat29OKAY_318.png', 'Pat29OKAY_319.png', 'Pat29OKAY_320.png', 'Pat29OKAY_321.png', 'Pat29OKAY_322.png', 'Pat29OKAY_323.png', 'Pat29OKAY_324.png', 'Pat29OKAY_325.png', 'Pat29OKAY_326.png', 'Pat29OKAY_327.png', 'Pat29OKAY_328.png', 'Pat29OKAY_329.png', 'Pat29OKAY_330.png', 'Pat29OKAY_331.png', 'Pat29OKAY_332.png', 'Pat29OKAY_333.png', 'Pat29OKAY_334.png', 'Pat29OKAY_335.png', 'Pat29OKAY_336.png', 'Pat29OKAY_337.png', 'Pat29OKAY_338.png', 'Pat29OKAY_339.png', 'Pat29OKAY_340.png', 'Pat29OKAY_341.png', 'Pat29OKAY_342.png', 'Pat29OKAY_343.png', 'Pat29OKAY_344.png', 'Pat29OKAY_368.png', 'Pat29OKAY_369.png', 'Pat29OKAY_370.png', 'Pat29OKAY_371.png', 'Pat29OKAY_373.png', 'Pat29OKAY_374.png', 'Pat29OKAY_375.png', 'Pat29OKAY_376.png', 'Pat29OKAY_377.png', 'Pat29OKAY_383.png', 'Pat29OKAY_384.png', 'Pat29OKAY_385.png', 'Pat29OKAY_386.png', 'Pat29OKAY_387.png', 'Pat29OKAY_388.png', 'Pat29OKAY_389.png', 'Pat29OKAY_390.png', 'Pat29OKAY_391.png', 'Pat29OKAY_392.png', 'Pat29OKAY_396.png', 'Pat29OKAY_397.png', 'Pat29OKAY_398.png', 'Pat29OKAY_399.png', 'Pat29OKAY_400.png', 'Pat29OKAY_404.png', 'Pat29OKAY_426.png', 'Pat29OKAY_427.png', 'Pat29OKAY_428.png', 'Pat29OKAY_429.png', 'Pat29OKAY_430.png', 'Pat29OKAY_431.png', 'Pat29OKAY_432.png', 'Pat
Y_636.png', 'Pat29OKAY_637.png', 'Pat29OKAY_638.png', 'Pat29OKAY_639.png', 'Pat29OKAY_650.png', 'Pat29OKAY_651.png', 'Pat29OKAY_652.png', 'Pat29OKAY_653.png', 'Pat29OKAY_654.png', 'Pat29OKAY_655.png', 'Pat29OKAY_656.png', 'Pat29OKAY_657.png', 'Pat29OKAY_658.png', 'Pat29OKAY_659.png', 'Pat29OKAY_660.png', 'Pat29OKAY_661.png', 'Pat29OKAY_662.png', 'Pat29OKAY_663.png', 'Pat29OKAY_664.png', 'Pat29OKAY_665.png', 'Pat29OKAY_666.png', 'Pat29OKAY_667.png', 'Pat29OKAY_668.png', 'Pat29OKAY_669.png', 'Pat29OKA ...
# Anesthesia_Low
# ['Pat27LOW_614.png', 'Pat27LOW_615.png', 'Pat27LOW_616.png', 'Pat27LOW_726.png', 'Pat27LOW_727.png', 'Pat27LOW_728.png', 'Pat27LOW_729.png', 'Pat27LOW_730.png', 'Pat27LOW_731.png', 'Pat27LOW_1364.png', 'Pat27LOW_1379.png', 'Pat27LOW_1380.png', 'Pat27LOW_1381.png', 'Pat27LOW_1382.png', 'Pat27LOW_1383.png', 'Pat27LOW_1384.png', 'Pat27LOW_1385.png', 'Pat27LOW_1386.png', 'Pat27LOW_1387.png', 'Pat27LOW_1388.png', 'Pat27LOW_1389.png', 'Pat27LOW_1390.png', 'Pat27LOW_1391.png', 'Pat27LOW_1392.png', 'Pat27LOW_1393.png', 'Pat27LOW_1394.png', 'Pat27LOW_1395.png', 'Pat27LOW_1396.png', 'Pat27LOW_1397.png', 'Pat27LOW_1400.png', 'Pat27LOW_1401.png', 'Pat27LOW_1402.png', 'Pat27LOW_1403.png', 'Pat27LOW_1404.png', 'Pat27LOW_1405.png', 'Pat27LOW_1406.png', 'Pat27LOW_1407.png', 'Pat27LOW_1408.png', 'Pat27LOW_1409.png', 'Pat27LOW_1410.png', 'Pat27LOW_1411.png', 'Pat27LOW_1412.png', 'Pat27LOW_1413.png', 'Pat27LOW_1414.png', 'Pat27LOW_1415.png', 'Pat27LOW_1422.png', 'Pat27LOW_1423.png', 'Pat27LOW_1424.png', 'Pat27LOW_1425.png', 'Pat27LOW_1426.png', 'Pat27LOW_1427.png', 'Pat27LOW_1428.png', 'Pat27LOW_1429.png', 'Pat27LOW_1430.png', 'Pat27LOW_1431.png', 'Pat27LOW_1432.png', 'Pat27LOW_1433.png', 'Pat27LOW_1434.png', 'Pat27LOW_1435.png', 'Pat27LOW_1436.png', 'Pat27LOW_1437.png', 'Pat27LOW_1438.png', 'Pat27LOW_1439.png', 'Pat27LOW_1440.png', 'Pat27LOW_1441.png', 'Pat27LOW_1442.png', 'Pat27LOW_1443.png', 'Pat27LOW_1444.png', 'Pat27LOW_1445.png', 'Pat27LOW_1446.png', 'Pat27LOW_1447.png', 'Pat27LOW_1448.png', 'Pat27LOW_1449.png', 'Pat27LOW_1450.png', 'Pat27LOW_1451.png', 'Pat27LOW_1452.png', 'Pat27LOW_1453.png', 'Pat27LOW_1454.png', 'Pat27LOW_1455.png', 'Pat27LOW_1456.png', 'Pat27LOW_1457.
png', 'Pat31DEEP_643.png', 'Pat31DEEP_644.png', 'Pat31DEEP_645.png', 'Pat31DEEP_646.png', 'Pat31DEEP_647.png', 'Pat31DEEP_648.png', 'Pat31DEEP_649.png', 'Pat31DEEP_653.png', 'Pat31DEEP_654.png', 'Pat31DEEP_655.png', 'Pat31DEEP_656.png', 'Pat31DEEP_761.png', 'Pat31DEEP_762.png', 'Pat31DEEP_763.png', 'Pat31DEEP_783.png', 'Pat31DEEP_784.png', 'Pat31DEEP_785.png', 'Pat31DEEP_786.png', 'Pat31DEEP_787.png', 'Pat31DEEP_788.png', 'Pat31DEEP_789.png', 'Pat31DEEP_790.png', 'Pat31DEEP_791.png', 'Pat31DEEP_792.png', 'Pat31DEEP_793.png', 'Pat31DEEP_794.png', 'Pat31DEEP_795.png', 'Pat31DEEP_796.png', 'Pat31DEEP_797.png', 'Pat31DEEP_798.png', 'Pat31DEEP_799.png', 'Pat31DEEP_800.png', 'Pat31DEEP_801.png', 'Pat31DEEP_802.png', 'Pat31DEEP_803.png', 'Pat31DEEP_804.png', 'Pat31DEEP_805.png', 'Pat31DEEP_806.png', 'Pat31DEEP_807.png', 'Pat31DEEP_808.png', 'Pat31DEEP_819.png', 'Pat31DEEP_820.png', 'Pat31DEEP_821.png', 'Pat31DEEP_822.png', 'Pat32DEEP_1.png', 'Pat32DEEP_2.png', 'Pat32DEEP_3.png', 'Pat32DEEP_4.png', 'Pat32DEEP_5.png', 'Pat32DEEP_6.png', 'Pat32DEEP_110.png', 'Pat32DEEP_111.png', 'Pat32DEEP_112.png', 'Pat32DEEP_113.png', 'Pat32DEEP_114.png', 'Pat32DEEP_115.png', 'Pat32DEEP_116.png', 'Pat32DEEP_117.png', 'Pat32DEEP_118.png', 'Pat32DEEP_119.png', 'Pat32DEEP_120.png', 'Pat32DEEP_121.png', 'Pat32DEEP_127.png', 'Pat32DEEP_140.png', 'Pat32DEEP_141.png', 'Pat32DEEP_142.png', 'Pat32DEEP_143.png', 'Pat32DEEP_144.png', 'Pat32DEEP_170.png', 'Pat32DEEP_171.png', 'Pat32DEEP_172.png', 'Pat32DEEP_173.png', 'Pat32DEEP_174.png', 'Pat32DEEP_175.png', 'Pat32DEEP_176.png', 'Pat32DEEP_177.png', 'Pat32DEEP_178.png', 'Pat32DEEP_179.png', 'Pat32DEEP_180.png', 'Pat32DEEP_181.png', 'Pat32DEEP_182.png', 'Pat32DEEP_183.png', 'Pat32DEEP_184.png', 'Pat32DEEP_185.png', 'Pat32DEEP_186.png', 'Pat32DEEP_187.png', 'Pat32DEEP_188.png', 'Pat32DEEP_189.png', 'Pat32DEEP_190.png', 'Pat32DEEP_191.png', 'Pat32DEEP_242.png', 'Pat32DEEP_261.png', 'Pat32DEEP_262.png', 'Pat32DEEP_263.png',  ...

# %%
for dataset in data_dir_list:
  img_list=os.listdir(data_path+'/' +dataset)
  print ('Loading the images of dataset-'+'{}\n'.format(dataset))
  label = labels_name[dataset]
  for img in img_list:
    input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
    input_img_resize=cv2.resize(input_img,(128,128))
    img_data_list.append(input_img_resize)
    labels_list.append(label)
# Out:
# Loading the images of dataset-Anesthesia_Okay
#
# Loading the images of dataset-Anesthesia_Low
#
# Loading the images of dataset-Anesthesia_Deep

# %%
img_data = np.array(img_data_list)
img_data = img_data.astype('float32')
img_data /= 255.
print (img_data.shape)
# Out:
# (13530, 128, 128, 3)

# %%
import keras
import keras.utils
from keras import utils as np_utils

labels = np.array(labels_list)
# print the count of number of samples for different classes
print(np.unique(labels,return_counts=True))
# convert class labels to on-hot encoding
Y = keras.utils.to_categorical(labels, num_classes)
# Out:
# (array([0, 1]), array([9020, 4510]))

# %%
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

#Shuffle the dataset
x,y = shuffle(img_data,Y, random_state=2)

# %%
# Split the dataset
x_train, x_test, y_train, y_test = train_test_split(img_data, Y, test_size=0.3)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (9471, 128, 128, 3)
# (4059, 128, 128, 3)
# (9471, 3)
# (4059, 3)

# %%
def show_random_eg(x,y,p):
    indices=np.random.choice(range(x.shape[0]),10,replace=False)
    x=x[indices]
    y=y[indices]
    p=p[indices]
    
    plt.figure(figsize=(20,10))
    
    for i in range(10):
        plt.subplot(2,5,i+1)
        plt.imshow(x[i])
        plt.xticks([])
        plt.yticks([])
        csfont = {'fontname':'Comic Sans MS'}
        hfont = {'fontname':'Helvetica'}
        col='purple' if np.argmax(y[i])==np.argmax(p[i]) else 'red'
        #print(class_names[np.argmax(p[i])])
        
        plt.xlabel(class_names[np.argmax(p[i])],color=col, fontsize=20,**hfont)
    plt.show()

# %%
show_random_eg(x_train, y_train, y_train)
# Out:
# findfont: Font family ['Helvetica'] not found. Falling back to DejaVu Sans.

# %%
show_random_eg(x_test, y_test, y_test)

# %%
input_shape=img_data[0].shape
input_shape
# Out:
# (128, 128, 3)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (9471, 128, 128, 3) (9471, 3)
# (4059, 128, 128, 3) (4059, 3)

# %% [markdown]
# # CHECKPOINT

# %%
from keras.callbacks import ModelCheckpoint
from keras.callbacks import LearningRateScheduler

# %%
class LearningRateSchedulerPerBatch(LearningRateScheduler):
    """ Callback class to modify the default learning rate scheduler to operate each batch"""
    def __init__(self, schedule, verbose=0):
        super(LearningRateSchedulerPerBatch, self).__init__(schedule, verbose)
        self.count = 0  # Global batch index (the regular batch argument refers to the batch index within the epoch)

    def on_epoch_begin(self, epoch, logs=None):
        pass

    def on_epoch_end(self, epoch, logs=None):
        pass

    def on_batch_begin(self, batch, logs=None):
        super(LearningRateSchedulerPerBatch, self).on_epoch_begin(self.count, logs)

    def on_batch_end(self, batch, logs=None):
        super(LearningRateSchedulerPerBatch, self).on_epoch_end(self.count, logs)
        self.count += 1

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.layers import Dropout, Flatten, Input, Dense ,Activation
from tensorflow.keras.optimizers import Adam

def create_model():
    
    def add_conv_block(model, num_filters):
        
        model.add(Conv2D(num_filters, 3, activation='relu', padding='same'))
        model.add(BatchNormalization())
        model.add(Conv2D(num_filters, 3, activation='relu', padding='valid'))
        model.add(MaxPooling2D(pool_size=2))
        model.add(Dropout(0.2))

        return model
    
    model = tf.keras.models.Sequential()
    model.add(Input(shape=(128, 128, 3)))
    model = add_conv_block(model,96)
    model = add_conv_block(model, 32)
    model = add_conv_block(model, 64)
    model = add_conv_block(model, 128)
    model = add_conv_block(model,256)
    
  

    
    model.add(Flatten())
    #model.add(Dense(4096))
   #model.add(Activation('tanh'))
   #model.add(Dropout(0.5))
   # model.add(Dense(4096))
   # model.add(Activation('relu'))
   # model.add(Dropout(0.5))
    model.add(Dense(3, activation='softmax'))
    opt =Adam(
    lr=0.0001,beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0
    )
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
    return model

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='cnn_eeg.png',show_shapes=True, show_layer_names=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-e3043b09af03> in <module>()
#       1 from keras.utils.vis_utils import plot_model
# ----> 2 plot_model(model, to_file='cnn_eeg.png',show_shapes=True, show_layer_names=True)
#
# NameError: name 'model' is not defined

# %%
if not os.path.isdir('/content/drive/My Drive/Colab Notebooks/modelsEEG'):
    os.mkdir('/content/drive/My Drive/Colab Notebooks/modelsEEG')

# %%
model = create_model()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 128, 128, 96)      2688
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128, 128, 96)      384
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 126, 126, 96)      83040
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 63, 63, 96)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 63, 63, 96)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 63, 63, 32)        27680
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 63, 63, 32)        128
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 61, 61, 32)        9248
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 30, 30, 32)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 30, 30, 64)        18496
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 30, 30, 64)        256
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 28, 28, 64)        36928
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 14, 14, 64)        0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 14, 14, 128)       73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 12, 12, 128)       147584
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 6, 6, 256)         295168
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 4, 4, 256)         590080
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 3075
# =================================================================
# Total params: 1,290,147
# Trainable params: 1,288,995
# Non-trainable params: 1,152
# _________________________________________________________________

# %%
# Start/resume training
#model.fit(x, y, callbacks=callbacks, initial_epoch=initial_epoch)

#Training
h=model.fit(
x_train,y_train,
validation_data=(x_test,y_test),
epochs=50,batch_size=64,
callbacks=[ tf.keras.callbacks.ModelCheckpoint('/content/drive/My Drive/Colab Notebooks/modelsEEG/new_bin_model_{epoch:03d}_{val_accuracy:.3f}.h5', 
                                            save_best_only=True,
                                            save_weights_only=False,
                                            monitor='val_accuracy')
          ],
initial_epoch=0

)
# Out:
# Epoch 1/50
# 148/148 [==============================] - 65s 439ms/step - loss: 0.5715 - accuracy: 0.5916 - val_loss: 0.7145 - val_accuracy: 0.0000e+00
# Epoch 2/50
# 148/148 [==============================] - 65s 439ms/step - loss: 0.4977 - accuracy: 0.6204 - val_loss: 0.6221 - val_accuracy: 0.6659
# Epoch 3/50
# 148/148 [==============================] - 65s 438ms/step - loss: 0.4508 - accuracy: 0.6522 - val_loss: 0.5121 - val_accuracy: 0.6706
# Epoch 4/50
# 148/148 [==============================] - 65s 437ms/step - loss: 0.4225 - accuracy: 0.6772 - val_loss: 0.4061 - val_accuracy: 0.7221
# Epoch 5/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.4006 - accuracy: 0.6973 - val_loss: 0.3771 - val_accuracy: 0.7118
# Epoch 6/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.3829 - accuracy: 0.7110 - val_loss: 0.3671 - val_accuracy: 0.7174
# Epoch 7/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.3751 - accuracy: 0.7157 - val_loss: 0.5222 - val_accuracy: 0.5161
# Epoch 8/50
# 148/148 [==============================] - 64s 434ms/step - loss: 0.3590 - accuracy: 0.7286 - val_loss: 0.3589 - val_accuracy: 0.7283
# Epoch 9/50
# 148/148 [==============================] - 65s 436ms/step - loss: 0.3435 - accuracy: 0.7482 - val_loss: 0.4011 - val_accuracy: 0.6706
# Epoch 10/50
# 148/148 [==============================] - 65s 438ms/step - loss: 0.3413 - accuracy: 0.7517 - val_loss: 0.3217 - val_accuracy: 0.7719
# Epoch 11/50
# 148/148 [==============================] - 65s 438ms/step - loss: 0.3282 - accuracy: 0.7632 - val_loss: 0.3211 - val_accuracy: 0.7746
# Epoch 12/50
# 148/148 [==============================] - 65s 437ms/step - loss: 0.3282 - accuracy: 0.7654 - val_loss: 0.3510 - val_accuracy: 0.7275
# Epoch 13/50
# 148/148 [==============================] - 65s 436ms/step - loss: 0.3257 - accuracy: 0.7667 - val_loss: 0.4001 - val_accuracy: 0.6948
# Epoch 14/50
# 148/148 [==============================] - 64s 435ms/step - loss: 0.3196 - accuracy: 0.7717 - val_loss: 0.3697 - val_accuracy: 0.7206
# Epoch 15/50
# 148/148 [==============================] - 64s 435ms/step - loss: 0.3129 - accuracy: 0.7784 - val_loss: 0.3208 - val_accuracy: 0.7778
# Epoch 16/50
# 148/148 [==============================] - 65s 437ms/step - loss: 0.3068 - accuracy: 0.7835 - val_loss: 0.3019 - val_accuracy: 0.7970
# Epoch 17/50
# 148/148 [==============================] - 65s 437ms/step - loss: 0.3053 - accuracy: 0.7879 - val_loss: 0.3582 - val_accuracy: 0.7374
# Epoch 18/50
# 148/148 [==============================] - 65s 436ms/step - loss: 0.3020 - accuracy: 0.7899 - val_loss: 0.3690 - val_accuracy: 0.7263
# Epoch 19/50
# 148/148 [==============================] - 64s 434ms/step - loss: 0.2964 - accuracy: 0.7955 - val_loss: 0.3311 - val_accuracy: 0.7692
# Epoch 20/50
# 148/148 [==============================] - 64s 434ms/step - loss: 0.2947 - accuracy: 0.7960 - val_loss: 0.3132 - val_accuracy: 0.7765
# Epoch 21/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.2969 - accuracy: 0.7966 - val_loss: 0.3389 - val_accuracy: 0.7625
# Epoch 22/50
# 148/148 [==============================] - 64s 435ms/step - loss: 0.2890 - accuracy: 0.8051 - val_loss: 0.2868 - val_accuracy: 0.8066
# Epoch 23/50
# 148/148 [==============================] - 64s 434ms/step - loss: 0.2893 - accuracy: 0.8021 - val_loss: 0.3178 - val_accuracy: 0.7812
# Epoch 24/50
# 148/148 [==============================] - 64s 432ms/step - loss: 0.2887 - accuracy: 0.8029 - val_loss: 0.2969 - val_accuracy: 0.8012
# Epoch 25/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.2818 - accuracy: 0.8095 - val_loss: 0.2882 - val_accuracy: 0.8056
# Epoch 26/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.2823 - accuracy: 0.8113 - val_loss: 0.2891 - val_accuracy: 0.8032
# Epoch 27/50
# 148/148 [==============================] - 64s 435ms/step - loss: 0.2797 - accuracy: 0.8097 - val_loss: 0.2886 - val_accuracy: 0.8086
# Epoch 28/50
# 148/148 [==============================] - 65s 436ms/step - loss: 0.2792 - accuracy: 0.8107 - val_loss: 0.2849 - val_accuracy: 0.8123
# Epoch 29/50
# 148/148 [==============================] - 64s 434ms/step - loss: 0.2736 - accuracy: 0.8142 - val_loss: 0.2896 - val_accuracy: 0.8009
# Epoch 30/50
# 148/148 [==============================] - 64s 435ms/step - loss: 0.2716 - accuracy: 0.8180 - val_loss: 0.2807 - val_accuracy: 0.8211
# Epoch 31/50
# 148/148 [==============================] - 64s 432ms/step - loss: 0.2654 - accuracy: 0.8248 - val_loss: 0.2879 - val_accuracy: 0.8064
# Epoch 32/50
# 148/148 [==============================] - 64s 434ms/step - loss: 0.2670 - accuracy: 0.8237 - val_loss: 0.2670 - val_accuracy: 0.8221
# Epoch 33/50
# 148/148 [==============================] - 64s 432ms/step - loss: 0.2636 - accuracy: 0.8211 - val_loss: 0.2694 - val_accuracy: 0.8221
# Epoch 34/50
# 148/148 [==============================] - 64s 432ms/step - loss: 0.2611 - accuracy: 0.8253 - val_loss: 0.3075 - val_accuracy: 0.7800
# Epoch 35/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.2600 - accuracy: 0.8291 - val_loss: 0.2893 - val_accuracy: 0.8034
# Epoch 36/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.2579 - accuracy: 0.8298 - val_loss: 0.2888 - val_accuracy: 0.8066
# Epoch 37/50
# 148/148 [==============================] - 64s 432ms/step - loss: 0.2521 - accuracy: 0.8342 - val_loss: 0.2891 - val_accuracy: 0.8049
# Epoch 38/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.2525 - accuracy: 0.8324 - val_loss: 0.2729 - val_accuracy: 0.8211
# Epoch 39/50
# 148/148 [==============================] - 64s 434ms/step - loss: 0.2490 - accuracy: 0.8349 - val_loss: 0.2680 - val_accuracy: 0.8275
# Epoch 40/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.2480 - accuracy: 0.8404 - val_loss: 0.3086 - val_accuracy: 0.7827
# Epoch 41/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.2414 - accuracy: 0.8387 - val_loss: 0.3959 - val_accuracy: 0.7204
# Epoch 42/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.2448 - accuracy: 0.8401 - val_loss: 0.2796 - val_accuracy: 0.8137
# Epoch 43/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.2412 - accuracy: 0.8469 - val_loss: 0.2773 - val_accuracy: 0.8165
# Epoch 44/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.2350 - accuracy: 0.8456 - val_loss: 0.2910 - val_accuracy: 0.8014
# Epoch 45/50
# 148/148 [==============================] - 64s 432ms/step - loss: 0.2339 - accuracy: 0.8505 - val_loss: 0.2945 - val_accuracy: 0.7992
# Epoch 46/50
# 148/148 [==============================] - 64s 432ms/step - loss: 0.2299 - accuracy: 0.8484 - val_loss: 0.2965 - val_accuracy: 0.8056
# Epoch 47/50
# 148/148 [==============================] - 64s 434ms/step - loss: 0.2292 - accuracy: 0.8529 - val_loss: 0.2703 - val_accuracy: 0.8283
# Epoch 48/50
# 148/148 [==============================] - 64s 435ms/step - loss: 0.2232 - accuracy: 0.8527 - val_loss: 0.2600 - val_accuracy: 0.8332
# Epoch 49/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.2250 - accuracy: 0.8499 - val_loss: 0.2734 - val_accuracy: 0.8216
# Epoch 50/50
# 148/148 [==============================] - 64s 433ms/step - loss: 0.2205 - accuracy: 0.8582 - val_loss: 0.2897 - val_accuracy: 0.8049

# %%
model = tf.keras.models.load_model('/content/drive/My Drive/Colab Notebooks/modelsEEG/new_bin_model_048_0.833.h5')

# %%
results = model.evaluate(x_train, y_train, batch_size=64)
print('Train accuracy:', results[1]*100)
# Out:
# 148/148 [==============================] - 16s 108ms/step - loss: 0.1947 - accuracy: 0.8782
# Train accuracy: 87.81543374061584

# %%
results = model.evaluate(x_test, y_test, batch_size=64)
print('Test accuracy:', results[1]*100)
# Out:
# 64/64 [==============================] - 7s 105ms/step - loss: 0.2600 - accuracy: 0.8332
# Test accuracy: 83.32101702690125

# %%
#Final predictions

losses = h.history['loss']
accs = h.history['accuracy']
val_losses = h.history['val_loss']
val_accs = h.history['val_accuracy']
epochs = len(losses)

plt.figure(figsize=(12, 4))
for i, metrics in enumerate(zip([losses, accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %%
model = tf.keras.models.load_model('/content/drive/My Drive/Colab Notebooks/modelsEEG/new_bin_model_024_0.825.h5')
preds = model.predict(x_test)

# %%
show_random_eg(x_test, y_test, preds)

# %%
from sklearn.metrics import classification_report, confusion_matrix
  
# confusion matrix in sklearn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# confusion matrix
matrix = confusion_matrix(y_test,preds, labels=['Anestesia Low','Anesthesia Deep','Anesthesia Okay'])
print('Confusion matrix : \n',matrix)

# outcome values order in sklearn
tp, fn, fp, tn = confusion_matrix(y_test,preds,labels=['Anestesia Low','Anesthesia Deep','Anesthesia Okay']).reshape(-1)
print('Outcome values : \n', tp, fn, fp, tn)

# classification report for precision, recall f1-score and accuracy
matrix = classification_report(y_test,preds,labels=['Anestesia Low','Anesthesia Deep','Anesthesia Okay'])
print('Classification report : \n',matrix)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-a36434985e54> in <module>()
#       6
#       7 # confusion matrix
# ----> 8 matrix = confusion_matrix(y_test,preds, labels=['Anestesia Low','Anesthesia Deep','Anesthesia Okay'])
#       9 print('Confusion matrix : \n',matrix)
#      10
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     266
#     267     """
# --> 268     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     269     if y_type not in ("binary", "multiclass"):
#     270         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      88     if len(y_type) > 1:
#      89         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 90                          "and {1} targets".format(type_true, type_pred))
#      91
#      92     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of multilabel-indicator and continuous-multioutput targets

# %% [markdown]
# # jhkhkjh

# %%
# Create model


model = Sequential()

model.add(Convolution2D(32, 3,3,border_mode='same',input_shape=input_shape))
model.add(Activation('relu'))
model.add(Convolution2D(32, 3, 3))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Convolution2D(64, 3, 3))
model.add(Activation('relu'))
#model.add(Convolution2D(64, 3, 3))
#model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

#sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
#model.compile(loss='categorical_crossentropy', optimizer=sgd,metrics=["accuracy"])
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=["accuracy"])
# Out:
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(128, 128,..., padding="same")`
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3))`
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`
#   del sys.path[0]
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.

# %%
# Viewing model_configuration

model.summary()
model.get_config()
model.layers[0].get_config()
model.layers[0].input_shape			
model.layers[0].output_shape			
model.layers[0].get_weights()
np.shape(model.layers[0].get_weights()[0])
model.layers[0].trainable
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      896
# _________________________________________________________________
# activation_1 (Activation)    (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 126, 126, 32)      9248
# _________________________________________________________________
# activation_2 (Activation)    (None, 126, 126, 32)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# activation_3 (Activation)    (None, 61, 61, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 30, 30, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 57600)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                3686464
# _________________________________________________________________
# activation_4 (Activation)    (None, 64)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 195
# _________________________________________________________________
# activation_5 (Activation)    (None, 3)                 0
# =================================================================
# Total params: 3,715,299
# Trainable params: 3,715,299
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
# True

# %%
# Training
#hist = model.fit(X_train, y_train, batch_size=16, nb_epoch=num_epoch, verbose=1, validation_data=(X_test, y_test))
hist = model.fit(X_train, y_train, batch_size=batch_size, nb_epoch=num_epoch,verbose=1, validation_split=0.2)
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   This is separate from the ipykernel package so we can avoid doing imports until
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\Admin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 3744 samples, validate on 936 samples
# Epoch 1/50
# 3744/3744 [==============================] - 241s 64ms/step - loss: 1.2156 - acc: 0.5182 - val_loss: 0.9303 - val_acc: 0.6303
# Epoch 2/50
# 3744/3744 [==============================] - 172s 46ms/step - loss: 0.9021 - acc: 0.6114 - val_loss: 0.8906 - val_acc: 0.6485
# Epoch 3/50
# 3744/3744 [==============================] - 168s 45ms/step - loss: 0.8382 - acc: 0.6370 - val_loss: 0.8273 - val_acc: 0.6795
# Epoch 4/50
# 3744/3744 [==============================] - 159s 42ms/step - loss: 0.7751 - acc: 0.6653 - val_loss: 0.7599 - val_acc: 0.6859
# Epoch 5/50
# 3744/3744 [==============================] - 258s 69ms/step - loss: 0.7271 - acc: 0.6763 - val_loss: 0.7813 - val_acc: 0.6848
# Epoch 6/50
# 3744/3744 [==============================] - 178s 47ms/step - loss: 0.7014 - acc: 0.6835 - val_loss: 0.7494 - val_acc: 0.6912
# Epoch 7/50
# 1160/3744 [========>.....................] - ETA: 1:45 - loss: 0.6721 - acc: 0.6819

# %%
# visualizing losses and accuracy
train_loss=hist.history['loss']
val_loss=hist.history['val_loss']
train_acc=hist.history['acc']
val_acc=hist.history['val_acc']
xc=range(num_epoch)

plt.figure(1,figsize=(7,5))
plt.plot(xc,train_loss)
plt.plot(xc,val_loss)
plt.xlabel('num of Epochs')
plt.ylabel('loss')
plt.title('train_loss vs val_loss')
plt.grid(True)
plt.legend(['train','val'])
#print plt.style.available # use bmh, classic,ggplot for big pictures
plt.style.use(['classic'])

plt.figure(2,figsize=(7,5))
plt.plot(xc,train_acc)
plt.plot(xc,val_acc)
plt.xlabel('num of Epochs')
plt.ylabel('accuracy')
plt.title('train_acc vs val_acc')
plt.grid(True)
plt.legend(['train','val'],loc=4)
#print plt.style.available # use bmh, classic,ggplot for big pictures
plt.style.use(['classic'])

# %%
# Evaluating the model

score = model.evaluate(X_test, y_test, show_accuracy=True, verbose=0)
print('Test Loss:', score[0])
print('Test accuracy:', score[1])

test_image = X_test[0:1]
print (test_image.shape)

print(model.predict(test_image))
print(model.predict_classes(test_image))
print(y_test[0:1])

# %%
model.evaluate(X_test, Y_test)[1]
